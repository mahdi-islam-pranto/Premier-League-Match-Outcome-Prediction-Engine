# %% [markdown]
# - Data source will be: https://datahub.io/football/english-premier-league
# - There are multiple APIs for the csv files of each season
# - There is a readme.md file for the data source
# - Gather all the API endpoints and convert the responses to dataframes and make it a one dataframe (this will be the final dataset)
